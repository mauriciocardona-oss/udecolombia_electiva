# %%
print("Hello Word")
# Out:
# Hello Word

# %%
# Exponencial
print(3**3)
# Out:
# 27

# %%
# Modulo de division
print(7//3)
# Out:
# 2

# %%
# Residuo de division
print(15 % 4)
# Out:
# 3

# %% [markdown]
# ## Tipos de variables

# %%
first_name = 'Mauricio'
last_name = "Cardona"
city = "Medellin"
Age = 250
is_married = False

# %%
# Asignacion multiple

primer_name, apellido, ciudad, edad, is_casado = ('Mauricio',"Cardona","Medellin",250, False )

# %%
# Asignacion multiple 
X_test, x_train, Y_test, y_train = (11,22,33,44) 
print(X_test, Y_test)

# %%
function_tmp = ('100 Unidades X', '200 Unidades de Y', '70%', 30)

X_test  = function_tmp[0]
x_train = function_tmp[1]
Y_test  = function_tmp[2]
y_train = function_tmp[3]

# %%
print(Y_test)
# Out:
# 70%

# %%
# Lista
skilks = ['HTML', 'CSS', 'DAX', 'JS', 'React', 'Python']

# Dictionario
person_info = {
    'first_name' : 'Mauricio',
    'last_name' : "Cardona",
    'city' : "Medellin",
    'Age' : 250,
    'is_married' : False
}

# %%
# Imprimir todos los valores almacenados

print("Nombre: ", first_name)
print("Apellido: ", last_name)
print("Nombre Completo: ", first_name, last_name)
print("Edad: ", Age)
# Out:
# Nombre:  Mauricio
# Apellido:  Cardona
# Nombre Completo:  Mauricio Cardona
# Edad:  250

# %%
# Imprimir el diccionario
print(person_info)
# Out:
# {'first_name': 'Mauricio', 'last_name': 'Cardona', 'city': 'Medellin', 'Age': 250, 'is_married': False}
